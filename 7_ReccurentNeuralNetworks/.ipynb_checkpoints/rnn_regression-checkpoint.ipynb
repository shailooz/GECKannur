# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
# Out:
# WARNING:tensorflow:From C:\Users\shail\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data = pd.read_csv('weather.csv')
seq = data.iloc[:,:].values
print(seq)
# Out:
# [[ 8.  24.3  0.   3.4  6.3]
#  [14.  26.9  3.6  4.4  9.7]
#  [13.7 23.4  3.6  5.8  3.3]
#  ...
#  [12.5 19.9  0.   8.4  5.3]
#  [12.5 26.9  0.   5.   7.1]
#  [12.3 30.2  0.   6.  12.6]]

# %%
look_back = 2
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back)]
		dataX.append(a)
		dataY.append(dataset[i + look_back])
	return np.array(dataX), np.array(dataY)
 
scaler = MinMaxScaler(feature_range=(-1, 1))
seq_scaled = scaler.fit_transform(seq)

seq_train = seq_scaled[:300,:]
seq_test = seq_scaled[300:,:]
X_train,Y_train= create_dataset(seq_train,look_back)
X_test,Y_test= create_dataset(seq_test,look_back)
print(X_train)
print(Y_train)
# Out:
# [[[ 0.01526718  0.18439716 -1.         -0.52941176 -0.07352941]
#   [ 0.47328244  0.36879433 -0.81909548 -0.38235294  0.42647059]]
#
#  [[ 0.47328244  0.36879433 -0.81909548 -0.38235294  0.42647059]
#   [ 0.45038168  0.12056738 -0.81909548 -0.17647059 -0.51470588]]
#
#  [[ 0.45038168  0.12056738 -0.81909548 -0.17647059 -0.51470588]
#   [ 0.41984733 -0.43971631  1.          0.02941176  0.33823529]]
#
#  ...
#
#  [[-0.41221374 -0.53900709 -1.         -0.58823529 -0.73529412]
#   [-0.64122137 -0.67375887 -1.         -0.64705882  0.02941176]]
#
#  [[-0.64122137 -0.67375887 -1.         -0.64705882  0.02941176]
#   [-0.41984733 -0.71631206 -1.         -0.23529412  0.39705882]]
#
#  [[-0.41984733 -0.71631206 -1.         -0.23529412  0.39705882]
#   [-0.8778626  -0.5177305  -1.         -0.64705882  0.52941176]]]
# [[ 0.45038168  0.12056738 -0.81909548 -0.17647059 -0.51470588]
#  [ 0.41984733 -0.43971631  1.          0.02941176  0.33823529]
#  [-0.01526718 -0.39716312 -0.85929648 -0.20588235  0.55882353]
#  ...
#  [-0.41984733 -0.71631206 -1.         -0.23529412  0.39705882]
#  [-0.8778626  -0.5177305  -1.         -0.64705882  0.52941176]
#  [-0.66412214 -0.53191489 -1.         -0.64705882  0.14705882]]

# %%
model = keras.Sequential()
model.add(layers.SimpleRNN(50, input_shape=(look_back,5)))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(5))
model.compile(loss='mean_squared_error', optimizer="RMSProp")
model.fit(X_train, Y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\shail\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\shail\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 5/5 [==============================] - 1s 3ms/step - loss: 0.3349
# Epoch 2/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1804
# Epoch 3/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1458
# Epoch 4/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1297
# Epoch 5/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1226
# Epoch 6/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1224
# Epoch 7/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1183
# Epoch 8/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1171
# Epoch 9/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1119
# Epoch 10/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1060
# Epoch 11/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1076
# Epoch 12/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1076
# Epoch 13/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1066
# Epoch 14/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1026
# Epoch 15/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0990
# Epoch 16/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0968
# Epoch 17/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 18/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0976
# Epoch 19/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0954
# Epoch 20/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0941
# Epoch 21/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0956
# Epoch 22/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0935
# Epoch 23/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0925
# Epoch 24/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0903
# Epoch 25/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0927
# Epoch 26/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0893
# Epoch 27/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0891
# Epoch 28/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0916
# Epoch 29/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0904
# Epoch 30/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0927
# Epoch 31/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0901
# Epoch 32/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0883
# Epoch 33/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0893
# Epoch 34/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0883
# Epoch 35/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0851
# Epoch 36/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0878
# Epoch 37/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0863
# Epoch 38/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0885
# Epoch 39/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0860
# Epoch 40/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0879
# Epoch 41/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0856
# Epoch 42/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0856
# Epoch 43/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 44/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0850
# Epoch 45/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0848
# Epoch 46/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0863
# Epoch 47/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0842
# Epoch 48/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0832
# Epoch 49/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0850
# Epoch 50/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0873
# Epoch 51/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0810
# Epoch 52/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0833
# Epoch 53/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0835
# Epoch 54/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0859
# Epoch 55/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0820
# Epoch 56/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0843
# Epoch 57/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0803
# Epoch 58/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0832
# Epoch 59/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0837
# Epoch 60/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0854
# Epoch 61/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0830
# Epoch 62/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0843
# Epoch 63/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0843
# Epoch 64/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0803
# Epoch 65/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0806
# Epoch 66/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0824
# Epoch 67/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0830
# Epoch 68/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0817
# Epoch 69/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0805
# Epoch 70/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0834
# Epoch 71/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0819
# Epoch 72/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0812
# Epoch 73/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0834
# Epoch 74/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0796
# Epoch 75/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0821
# Epoch 76/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0795
# Epoch 77/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0817
# Epoch 78/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0794
# Epoch 79/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0793
# Epoch 80/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0806
# Epoch 81/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0790
# Epoch 82/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0823
# Epoch 83/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0788
# Epoch 84/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0781
# Epoch 85/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0789
# Epoch 86/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0785
# Epoch 87/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0812
# Epoch 88/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0805
# Epoch 89/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0781
# Epoch 90/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0793
# Epoch 91/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0802
# Epoch 92/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0788
# Epoch 93/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0791
# Epoch 94/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0781
# Epoch 95/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0791
# Epoch 96/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0795
# Epoch 97/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0813
# Epoch 98/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0814
# Epoch 99/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0798
# Epoch 100/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0794

# %%
seq_train_pred_scaled = model.predict(X_train)
seq_train_pred = scaler.inverse_transform(seq_train_pred_scaled)
X_train_org = scaler.inverse_transform(seq_train)
print(seq_train_pred)
for i in range(5):
  plt.plot(X_train_org[:,i],label='True')
  plt.plot(seq_train_pred[:,i],label='Predicted')
  plt.legend()
  plt.show()
# Out:
# 10/10 [==============================] - 0s 2ms/step
# [[12.301071   25.032925    0.40482938  6.108729    8.188965  ]
#  [13.047172   23.315678    4.568484    4.4873934   6.778309  ]
#  [ 5.934051   19.054667    5.2112374   4.470899   12.055871  ]
#  ...
#  [-0.38064831 12.848047   -0.3389065   1.576413    6.7492146 ]
#  [ 0.03807157 13.264416   -0.9167523   3.0218523   8.424216  ]
#  [-0.68581337 15.616192   -1.4094052   2.874279    8.224947  ]]

# %%
seq_test_pred_scaled = model.predict(X_train)
seq_test_pred = scaler.inverse_transform(seq_test_pred_scaled)
X_test_org = scaler.inverse_transform(seq_test)
print(seq_pred)
for i in range(5):
  plt.plot(X_test_org[:,i],label='True')
  plt.plot(seq_test_pred[:,i],label='Predicted')
  plt.legend()
  plt.show()
# Out:
# 10/10 [==============================] - 0s 1ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 seq_test_pred = scaler.inverse_transform(seq_test_pred_scaled)
#       3 X_test_org = scaler.inverse_transform(seq_train)
# ----> 4 print(seq_pred)
#       5 for i in range(5):
#       6   plt.plot(X_test_org[:,i],label='True')
#
# NameError: name 'seq_pred' is not defined
